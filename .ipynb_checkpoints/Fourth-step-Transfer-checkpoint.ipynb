# %% [markdown]
# ### Importing The Required Libraries:

# %%
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer

tf.__version__
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)


import pickle
import numpy as np

import os
import os.path

import string
from itertools import chain

# %%
filename = "qa-1M"
tokenizer = pickle.load(open('tokenizer/tokenizer-' + filename + '.pkl', 'rb'))

# %%
file = open("data/" + filename + ".txt", "r", encoding = "utf8")
lines = []
l = 0
for i in file:
    lines.append(i)
    l = l + 1
    if (l > 5):
        print("The First Line: ", lines[0])
        print("The Last Line: ", lines[-1])
    else:
        print(len(lines[0]))
data = ""

for i in lines:
    data = ' '. join(lines)

data = data.replace('\n', '').replace('\r', '').replace('\ufeff', '')

data[:360]
# Out:
# 1120914
# "Are you a fan of Google or Microsoft? Both are excellent technology they are helpful in many ways. For the security purpose both are super.  I'm not  a huge fan of Google, but I use it a lot because I have to. I think they are a monopoly in some sense.   Google provides online related services and products, which includes online ads, search engine and cloud "

# %%
sequence_data = tokenizer.texts_to_sequences([data])[0]
sequence_data[:10]

vocab_size = len(tokenizer.word_index) + 1
print(vocab_size)
# Out:
# 10457

# %%
segments = 100
def defieData(num):
    sequences = []
    ind = int(len(sequence_data)/segments)
    for i in range(1, ind):        
        words = sequence_data[(ind*num)+i-1:(ind*num)+i+1]
        sequences.append(words)

    #print("The Length of sequences are: ", len(sequences))
    sequences = np.array(sequences)
    #sequences[:10]


    X = []
    y = []

    for i in sequences:
        X.append(i[0])
        y.append(i[1])

    X = np.array(X)
    y = np.array(y)
    #print("The Data is: ", X[:5])
    #print("The responses are: ", y[:5])

    y = to_categorical(y, num_classes=vocab_size)
    #y[:5]
    return X,y

# %%
model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=1))
model.add(LSTM(1000, return_sequences=True))
model.add(LSTM(1000))
model.add(Dense(1000, activation="relu"))
model.add(Dense(vocab_size, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1, 10)             104570
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 1000)           4044000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1000)              8004000
# _________________________________________________________________
# dense (Dense)                (None, 1000)              1001000
# _________________________________________________________________
# dense_1 (Dense)              (None, 10457)             10467457
# =================================================================
# Total params: 23,621,027
# Trainable params: 23,621,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras.utils import plot_model


keras.utils.plot_model(model, to_file='model.png', show_layer_names=False)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard

checkpoint = ModelCheckpoint("nextword-"+filename+".h5", monitor='loss', verbose=1,
    save_best_only=True, mode='auto')

reduce = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=3, min_lr=0.0001, verbose = 1)

logdir='logsnextword'+filename
tensorboard_Visualization = TensorBoard(log_dir=logdir)

model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.001))

# %%
X,y = defieData(0)
model.fit(X, y, epochs=1, batch_size=64, callbacks=[checkpoint, reduce, tensorboard_Visualization])
# Out:
# 33/33 [==============================] - 8s 32ms/step - loss: 8.3795
#
# Epoch 00001: loss improved from inf to 8.37945, saving model to nextword-qa-1M.h5

# %%
from tensorflow.keras.models import load_model
new_model = load_model('nextword-'+filename+'.h5')
checkpoint = ModelCheckpoint("nextword-"+filename+".h5", monitor='loss', verbose=1,
    save_best_only=True, mode='auto')

reduce = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=3, min_lr=0.0001, verbose = 1)

# %%
for num in range(1, segments):
    print(str(num)+"\n\n\n\n")
    X,y = defieData(num)
    new_model = load_model('nextword-'+filename+'.h5')
    new_model.fit(X, y, epochs=50, batch_size=64, callbacks=[checkpoint, reduce, tensorboard_Visualization])
    del new_model,X,y
# Out:
# 1
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 3s 30ms/step - loss: 6.9555
#
# Epoch 00001: loss improved from inf to 6.95545, saving model to nextword-qa-1M.h5
# Epoch 2/50
# 33/33 [==============================] - 0s 12ms/step - loss: 6.0701
#
# Epoch 00002: loss improved from 6.95545 to 6.07010, saving model to nextword-qa-1M.h5
# Epoch 3/50
# 33/33 [==============================] - 0s 12ms/step - loss: 5.7849
#
# Epoch 00003: loss improved from 6.07010 to 5.78488, saving model to nextword-qa-1M.h5
# Epoch 4/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.6476
#
# Epoch 00004: loss improved from 5.78488 to 5.64757, saving model to nextword-qa-1M.h5
# Epoch 5/50
# 33/33 [==============================] - 0s 12ms/step - loss: 5.5861
#
# Epoch 00005: loss improved from 5.64757 to 5.58606, saving model to nextword-qa-1M.h5
# Epoch 6/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.5469
#
# Epoch 00006: loss improved from 5.58606 to 5.54685, saving model to nextword-qa-1M.h5
# Epoch 7/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.5241
#
# Epoch 00007: loss improved from 5.54685 to 5.52408, saving model to nextword-qa-1M.h5
# Epoch 8/50
# 33/33 [==============================] - 0s 11ms/step - loss: 5.4998
#
# Epoch 00008: loss improved from 5.52408 to 5.49975, saving model to nextword-qa-1M.h5
# Epoch 9/50
# 33/33 [==============================] - 0s 11ms/step - loss: 5.4840
#
# Epoch 00009: loss improved from 5.49975 to 5.48396, saving model to nextword-qa-1M.h5
# Epoch 10/50
# 33/33 [==============================] - 0s 11ms/step - loss: 5.4649
#
# Epoch 00010: loss improved from 5.48396 to 5.46492, saving model to nextword-qa-1M.h5
# Epoch 11/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.4274
#
# Epoch 00011: loss improved from 5.46492 to 5.42740, saving model to nextword-qa-1M.h5
# Epoch 12/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.3908
#
# Epoch 00012: loss improved from 5.42740 to 5.39077, saving model to nextword-qa-1M.h5
# Epoch 13/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.3307
#
# Epoch 00013: loss improved from 5.39077 to 5.33071, saving model to nextword-qa-1M.h5
# Epoch 14/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.2349
#
# Epoch 00014: loss improved from 5.33071 to 5.23493, saving model to nextword-qa-1M.h5
# Epoch 15/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.1341
#
# Epoch 00015: loss improved from 5.23493 to 5.13415, saving model to nextword-qa-1M.h5
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.0373
#
# Epoch 00016: loss improved from 5.13415 to 5.03728, saving model to nextword-qa-1M.h5
# Epoch 17/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.9048
#
# Epoch 00017: loss improved from 5.03728 to 4.90482, saving model to nextword-qa-1M.h5
# Epoch 18/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.8159
#
# Epoch 00018: loss improved from 4.90482 to 4.81589, saving model to nextword-qa-1M.h5
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7154
#
# Epoch 00019: loss improved from 4.81589 to 4.71538, saving model to nextword-qa-1M.h5
# Epoch 20/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.6224
#
# Epoch 00020: loss improved from 4.71538 to 4.62236, saving model to nextword-qa-1M.h5
# Epoch 21/50
# 33/33 [==============================] - 0s 11ms/step - loss: 4.5577
#
# Epoch 00021: loss improved from 4.62236 to 4.55774, saving model to nextword-qa-1M.h5
# Epoch 22/50
# 33/33 [==============================] - 0s 11ms/step - loss: 4.4962
#
# Epoch 00022: loss improved from 4.55774 to 4.49621, saving model to nextword-qa-1M.h5
# Epoch 23/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.4518
#
# Epoch 00023: loss improved from 4.49621 to 4.45184, saving model to nextword-qa-1M.h5
# Epoch 24/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.3903
#
# Epoch 00024: loss improved from 4.45184 to 4.39026, saving model to nextword-qa-1M.h5
# Epoch 25/50
# 33/33 [==============================] - 0s 11ms/step - loss: 4.3303
#
# Epoch 00025: loss improved from 4.39026 to 4.33025, saving model to nextword-qa-1M.h5
# Epoch 26/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.3122
#
# Epoch 00026: loss improved from 4.33025 to 4.31220, saving model to nextword-qa-1M.h5
# Epoch 27/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.2517
#
# Epoch 00027: loss improved from 4.31220 to 4.25175, saving model to nextword-qa-1M.h5
# Epoch 28/50
# 33/33 [==============================] - 0s 11ms/step - loss: 4.2324
#
# Epoch 00028: loss improved from 4.25175 to 4.23242, saving model to nextword-qa-1M.h5
# Epoch 29/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.1845
#
# Epoch 00029: loss improved from 4.23242 to 4.18448, saving model to nextword-qa-1M.h5
# Epoch 30/50
# 33/33 [==============================] - 0s 11ms/step - loss: 4.1213
#
# Epoch 00030: loss improved from 4.18448 to 4.12130, saving model to nextword-qa-1M.h5
# Epoch 31/50
# 33/33 [==============================] - 0s 11ms/step - loss: 4.0669
#
# Epoch 00031: loss improved from 4.12130 to 4.06693, saving model to nextword-qa-1M.h5
# Epoch 32/50
# 33/33 [==============================] - 0s 11ms/step - loss: 4.0287
#
# Epoch 00032: loss improved from 4.06693 to 4.02867, saving model to nextword-qa-1M.h5
# Epoch 33/50
# 33/33 [==============================] - 0s 11ms/step - loss: 3.9751
#
# Epoch 00033: loss improved from 4.02867 to 3.97509, saving model to nextword-qa-1M.h5
# Epoch 34/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.9003
#
# Epoch 00034: loss improved from 3.97509 to 3.90032, saving model to nextword-qa-1M.h5
# Epoch 35/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.8454
#
# Epoch 00035: loss improved from 3.90032 to 3.84539, saving model to nextword-qa-1M.h5
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8211
#
# Epoch 00036: loss improved from 3.84539 to 3.82107, saving model to nextword-qa-1M.h5
# Epoch 37/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7568
#
# Epoch 00037: loss improved from 3.82107 to 3.75679, saving model to nextword-qa-1M.h5
# Epoch 38/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.6805
#
# Epoch 00038: loss improved from 3.75679 to 3.68049, saving model to nextword-qa-1M.h5
# Epoch 39/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.6284
#
# Epoch 00039: loss improved from 3.68049 to 3.62841, saving model to nextword-qa-1M.h5
# Epoch 40/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.5744
#
# Epoch 00040: loss improved from 3.62841 to 3.57437, saving model to nextword-qa-1M.h5
# Epoch 41/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.5326
#
# Epoch 00041: loss improved from 3.57437 to 3.53263, saving model to nextword-qa-1M.h5
# Epoch 42/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.5090
#
# Epoch 00042: loss improved from 3.53263 to 3.50901, saving model to nextword-qa-1M.h5
# Epoch 43/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.4926
#
# Epoch 00043: loss improved from 3.50901 to 3.49260, saving model to nextword-qa-1M.h5
# Epoch 44/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4348
#
# Epoch 00044: loss improved from 3.49260 to 3.43481, saving model to nextword-qa-1M.h5
# Epoch 45/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.3788
#
# Epoch 00045: loss improved from 3.43481 to 3.37878, saving model to nextword-qa-1M.h5
# Epoch 46/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.3725
#
# Epoch 00046: loss improved from 3.37878 to 3.37254, saving model to nextword-qa-1M.h5
# Epoch 47/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.3279
#
# Epoch 00047: loss improved from 3.37254 to 3.32793, saving model to nextword-qa-1M.h5
# Epoch 48/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.2884
#
# Epoch 00048: loss improved from 3.32793 to 3.28845, saving model to nextword-qa-1M.h5
# Epoch 49/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.2747
#
# Epoch 00049: loss improved from 3.28845 to 3.27469, saving model to nextword-qa-1M.h5
# Epoch 50/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.2349
#
# Epoch 00050: loss improved from 3.27469 to 3.23487, saving model to nextword-qa-1M.h5
# 2
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 2s 27ms/step - loss: 8.0841
#
# Epoch 00001: loss did not improve from 3.23487
# Epoch 2/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.7293
#
# Epoch 00002: loss did not improve from 3.23487
# Epoch 3/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.2852
#
# Epoch 00003: loss did not improve from 3.23487
# Epoch 4/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.0829
#
# Epoch 00004: loss did not improve from 3.23487
# Epoch 5/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.9263
#
# Epoch 00005: loss did not improve from 3.23487
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7973
#
# Epoch 00006: loss did not improve from 3.23487
# Epoch 7/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.6840
#
# Epoch 00007: loss did not improve from 3.23487
# Epoch 8/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5667
#
# Epoch 00008: loss did not improve from 3.23487
# Epoch 9/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4610
#
# Epoch 00009: loss did not improve from 3.23487
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3548
#
# Epoch 00010: loss did not improve from 3.23487
# Epoch 11/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2474
#
# Epoch 00011: loss did not improve from 3.23487
# Epoch 12/50
# 33/33 [==============================] - 0s 8ms/step - loss: 4.1359
#
# Epoch 00012: loss did not improve from 3.23487
# Epoch 13/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0508
#
# Epoch 00013: loss did not improve from 3.23487
# Epoch 14/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9432
#
# Epoch 00014: loss did not improve from 3.23487
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8345
#
# Epoch 00015: loss did not improve from 3.23487
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7478
#
# Epoch 00016: loss did not improve from 3.23487
# Epoch 17/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6559
#
# Epoch 00017: loss did not improve from 3.23487
# Epoch 18/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6032
#
# Epoch 00018: loss did not improve from 3.23487
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5000
#
# Epoch 00019: loss did not improve from 3.23487
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4478
#
# Epoch 00020: loss did not improve from 3.23487
# Epoch 21/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3530
#
# Epoch 00021: loss did not improve from 3.23487
# Epoch 22/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.2870
#
# Epoch 00022: loss did not improve from 3.23487
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2338
#
# Epoch 00023: loss improved from 3.23487 to 3.23383, saving model to nextword-qa-1M.h5
# Epoch 24/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1966
#
# Epoch 00024: loss improved from 3.23383 to 3.19659, saving model to nextword-qa-1M.h5
# Epoch 25/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1227
#
# Epoch 00025: loss improved from 3.19659 to 3.12270, saving model to nextword-qa-1M.h5
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1315
#
# Epoch 00026: loss did not improve from 3.12270
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0503
#
# Epoch 00027: loss improved from 3.12270 to 3.05028, saving model to nextword-qa-1M.h5
# Epoch 28/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.9753
#
# Epoch 00028: loss improved from 3.05028 to 2.97529, saving model to nextword-qa-1M.h5
# Epoch 29/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.9448
#
# Epoch 00029: loss improved from 2.97529 to 2.94476, saving model to nextword-qa-1M.h5
# Epoch 30/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.9062
#
# Epoch 00030: loss improved from 2.94476 to 2.90617, saving model to nextword-qa-1M.h5
# Epoch 31/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.8942
#
# Epoch 00031: loss improved from 2.90617 to 2.89424, saving model to nextword-qa-1M.h5
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8331
#
# Epoch 00032: loss improved from 2.89424 to 2.83311, saving model to nextword-qa-1M.h5
# Epoch 33/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.8203
#
# Epoch 00033: loss improved from 2.83311 to 2.82026, saving model to nextword-qa-1M.h5
# Epoch 34/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7612
#
# Epoch 00034: loss improved from 2.82026 to 2.76119, saving model to nextword-qa-1M.h5
# Epoch 35/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7237
#
# Epoch 00035: loss improved from 2.76119 to 2.72370, saving model to nextword-qa-1M.h5
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.7102
#
# Epoch 00036: loss improved from 2.72370 to 2.71017, saving model to nextword-qa-1M.h5
# Epoch 37/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6643
#
# Epoch 00037: loss improved from 2.71017 to 2.66432, saving model to nextword-qa-1M.h5
# Epoch 38/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.6318
#
# Epoch 00038: loss improved from 2.66432 to 2.63181, saving model to nextword-qa-1M.h5
# Epoch 39/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.6081
#
# Epoch 00039: loss improved from 2.63181 to 2.60810, saving model to nextword-qa-1M.h5
# Epoch 40/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.6030
#
# Epoch 00040: loss improved from 2.60810 to 2.60296, saving model to nextword-qa-1M.h5
# Epoch 41/50
# 33/33 [==============================] - 0s 12ms/step - loss: 2.5657
#
# Epoch 00041: loss improved from 2.60296 to 2.56566, saving model to nextword-qa-1M.h5
# Epoch 42/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5326
#
# Epoch 00042: loss improved from 2.56566 to 2.53265, saving model to nextword-qa-1M.h5
# Epoch 43/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5122
#
# Epoch 00043: loss improved from 2.53265 to 2.51215, saving model to nextword-qa-1M.h5
# Epoch 44/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4952
#
# Epoch 00044: loss improved from 2.51215 to 2.49517, saving model to nextword-qa-1M.h5
# Epoch 45/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.4701
#
# Epoch 00045: loss improved from 2.49517 to 2.47007, saving model to nextword-qa-1M.h5
# Epoch 46/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.4588
#
# Epoch 00046: loss improved from 2.47007 to 2.45877, saving model to nextword-qa-1M.h5
# Epoch 47/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.4395
#
# Epoch 00047: loss improved from 2.45877 to 2.43950, saving model to nextword-qa-1M.h5
# Epoch 48/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4238
#
# Epoch 00048: loss improved from 2.43950 to 2.42376, saving model to nextword-qa-1M.h5
# Epoch 49/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.4428
#
# Epoch 00049: loss did not improve from 2.42376
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4058
#
# Epoch 00050: loss improved from 2.42376 to 2.40578, saving model to nextword-qa-1M.h5
# 3
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 2s 23ms/step - loss: 9.8636
#
# Epoch 00001: loss did not improve from 2.40578
# Epoch 2/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.9938
#
# Epoch 00002: loss did not improve from 2.40578
# Epoch 3/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.3279
#
# Epoch 00003: loss did not improve from 2.40578
# Epoch 4/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.9813
#
# Epoch 00004: loss did not improve from 2.40578
# Epoch 5/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.7204
#
# Epoch 00005: loss did not improve from 2.40578
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4826
#
# Epoch 00006: loss did not improve from 2.40578
# Epoch 7/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2773
#
# Epoch 00007: loss did not improve from 2.40578
# Epoch 8/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0907
#
# Epoch 00008: loss did not improve from 2.40578
# Epoch 9/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9050
#
# Epoch 00009: loss did not improve from 2.40578
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7599
#
# Epoch 00010: loss did not improve from 2.40578
# Epoch 11/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6153
#
# Epoch 00011: loss did not improve from 2.40578
# Epoch 12/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4823
#
# Epoch 00012: loss did not improve from 2.40578
# Epoch 13/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3690
#
# Epoch 00013: loss did not improve from 2.40578
# Epoch 14/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2637
#
# Epoch 00014: loss did not improve from 2.40578
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1975
#
# Epoch 00015: loss did not improve from 2.40578
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0871
#
# Epoch 00016: loss did not improve from 2.40578
# Epoch 17/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0477
#
# Epoch 00017: loss did not improve from 2.40578
# Epoch 18/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.9691
#
# Epoch 00018: loss did not improve from 2.40578
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.9143
#
# Epoch 00019: loss did not improve from 2.40578
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8369
#
# Epoch 00020: loss did not improve from 2.40578
# Epoch 21/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.7869
#
# Epoch 00021: loss did not improve from 2.40578
# Epoch 22/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.7299
#
# Epoch 00022: loss did not improve from 2.40578
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6897
#
# Epoch 00023: loss did not improve from 2.40578
# Epoch 24/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6587
#
# Epoch 00024: loss did not improve from 2.40578
# Epoch 25/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5817
#
# Epoch 00025: loss did not improve from 2.40578
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5775
#
# Epoch 00026: loss did not improve from 2.40578
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5295
#
# Epoch 00027: loss did not improve from 2.40578
# Epoch 28/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.5055
#
# Epoch 00028: loss did not improve from 2.40578
# Epoch 29/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5060
#
# Epoch 00029: loss did not improve from 2.40578
# Epoch 30/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4596
#
# Epoch 00030: loss did not improve from 2.40578
# Epoch 31/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4310
#
# Epoch 00031: loss did not improve from 2.40578
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4068
#
# Epoch 00032: loss did not improve from 2.40578
# Epoch 33/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4029
#
# Epoch 00033: loss improved from 2.40578 to 2.40294, saving model to nextword-qa-1M.h5
# Epoch 34/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.3737
#
# Epoch 00034: loss improved from 2.40294 to 2.37369, saving model to nextword-qa-1M.h5
# Epoch 35/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.3608
#
# Epoch 00035: loss improved from 2.37369 to 2.36077, saving model to nextword-qa-1M.h5
# Epoch 36/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.3399
#
# Epoch 00036: loss improved from 2.36077 to 2.33993, saving model to nextword-qa-1M.h5
# Epoch 37/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.3067
#
# Epoch 00037: loss improved from 2.33993 to 2.30667, saving model to nextword-qa-1M.h5
# Epoch 38/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.3084
#
# Epoch 00038: loss did not improve from 2.30667
# Epoch 39/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2740
#
# Epoch 00039: loss improved from 2.30667 to 2.27402, saving model to nextword-qa-1M.h5
# Epoch 40/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2720
#
# Epoch 00040: loss improved from 2.27402 to 2.27200, saving model to nextword-qa-1M.h5
# Epoch 41/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2741
#
# Epoch 00041: loss did not improve from 2.27200
# Epoch 42/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2612
#
# Epoch 00042: loss improved from 2.27200 to 2.26119, saving model to nextword-qa-1M.h5
# Epoch 43/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.2334
#
# Epoch 00043: loss improved from 2.26119 to 2.23339, saving model to nextword-qa-1M.h5
# Epoch 44/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.2361
#
# Epoch 00044: loss did not improve from 2.23339
# Epoch 45/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2012
#
# Epoch 00045: loss improved from 2.23339 to 2.20122, saving model to nextword-qa-1M.h5
# Epoch 46/50
# 33/33 [==============================] - 0s 12ms/step - loss: 2.1994
#
# Epoch 00046: loss improved from 2.20122 to 2.19939, saving model to nextword-qa-1M.h5
# Epoch 47/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.2041
#
# Epoch 00047: loss did not improve from 2.19939
# Epoch 48/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1959
#
# Epoch 00048: loss improved from 2.19939 to 2.19594, saving model to nextword-qa-1M.h5
# Epoch 49/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1689
#
# Epoch 00049: loss improved from 2.19594 to 2.16893, saving model to nextword-qa-1M.h5
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1833
#
# Epoch 00050: loss did not improve from 2.16893
# 4
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 3s 31ms/step - loss: 9.9750
#
# Epoch 00001: loss did not improve from 2.16893
# Epoch 2/50
# 33/33 [==============================] - 0s 11ms/step - loss: 5.8746
#
# Epoch 00002: loss did not improve from 2.16893
# Epoch 3/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.0774
#
# Epoch 00003: loss did not improve from 2.16893
# Epoch 4/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.6334
#
# Epoch 00004: loss did not improve from 2.16893
# Epoch 5/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2658
#
# Epoch 00005: loss did not improve from 2.16893
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9656
#
# Epoch 00006: loss did not improve from 2.16893
# Epoch 7/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6955
#
# Epoch 00007: loss did not improve from 2.16893
# Epoch 8/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4909
#
# Epoch 00008: loss did not improve from 2.16893
# Epoch 9/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3136
#
# Epoch 00009: loss did not improve from 2.16893
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1582
#
# Epoch 00010: loss did not improve from 2.16893
# Epoch 11/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0164
#
# Epoch 00011: loss did not improve from 2.16893
# Epoch 12/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8933
#
# Epoch 00012: loss did not improve from 2.16893
# Epoch 13/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7940
#
# Epoch 00013: loss did not improve from 2.16893
# Epoch 14/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7015
#
# Epoch 00014: loss did not improve from 2.16893
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6095
#
# Epoch 00015: loss did not improve from 2.16893
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5397
#
# Epoch 00016: loss did not improve from 2.16893
# Epoch 17/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.4693
#
# Epoch 00017: loss did not improve from 2.16893
# Epoch 18/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4211
#
# Epoch 00018: loss did not improve from 2.16893
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3671
#
# Epoch 00019: loss did not improve from 2.16893
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3225
#
# Epoch 00020: loss did not improve from 2.16893
# Epoch 21/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2907
#
# Epoch 00021: loss did not improve from 2.16893
# Epoch 22/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2619
#
# Epoch 00022: loss did not improve from 2.16893
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2244
#
# Epoch 00023: loss did not improve from 2.16893
# Epoch 24/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2304
#
# Epoch 00024: loss did not improve from 2.16893
# Epoch 25/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1988
#
# Epoch 00025: loss did not improve from 2.16893
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1665
#
# Epoch 00026: loss improved from 2.16893 to 2.16647, saving model to nextword-qa-1M.h5
# Epoch 27/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1717
#
# Epoch 00027: loss did not improve from 2.16647
# Epoch 28/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1321
#
# Epoch 00028: loss improved from 2.16647 to 2.13208, saving model to nextword-qa-1M.h5
# Epoch 29/50
# 33/33 [==============================] - 0s 12ms/step - loss: 2.1245
#
# Epoch 00029: loss improved from 2.13208 to 2.12450, saving model to nextword-qa-1M.h5
# Epoch 30/50
# 33/33 [==============================] - 0s 12ms/step - loss: 2.1012
#
# Epoch 00030: loss improved from 2.12450 to 2.10121, saving model to nextword-qa-1M.h5
# Epoch 31/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.0953
#
# Epoch 00031: loss improved from 2.10121 to 2.09534, saving model to nextword-qa-1M.h5
# Epoch 32/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0858
#
# Epoch 00032: loss improved from 2.09534 to 2.08578, saving model to nextword-qa-1M.h5
# Epoch 33/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0919
#
# Epoch 00033: loss did not improve from 2.08578
# Epoch 34/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0662
#
# Epoch 00034: loss improved from 2.08578 to 2.06616, saving model to nextword-qa-1M.h5
# Epoch 35/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.0544
#
# Epoch 00035: loss improved from 2.06616 to 2.05438, saving model to nextword-qa-1M.h5
# Epoch 36/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.0519
#
# Epoch 00036: loss improved from 2.05438 to 2.05188, saving model to nextword-qa-1M.h5
# Epoch 37/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.0412
#
# Epoch 00037: loss improved from 2.05188 to 2.04116, saving model to nextword-qa-1M.h5
# Epoch 38/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.0193
#
# Epoch 00038: loss improved from 2.04116 to 2.01929, saving model to nextword-qa-1M.h5
# Epoch 39/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0243
#
# Epoch 00039: loss did not improve from 2.01929
# Epoch 40/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0025
#
# Epoch 00040: loss improved from 2.01929 to 2.00246, saving model to nextword-qa-1M.h5
# Epoch 41/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9990
#
# Epoch 00041: loss improved from 2.00246 to 1.99902, saving model to nextword-qa-1M.h5
# Epoch 42/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.9835
#
# Epoch 00042: loss improved from 1.99902 to 1.98347, saving model to nextword-qa-1M.h5
# Epoch 43/50
# 33/33 [==============================] - 0s 11ms/step - loss: 1.9938
#
# Epoch 00043: loss did not improve from 1.98347
# Epoch 44/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9817
#
# Epoch 00044: loss improved from 1.98347 to 1.98174, saving model to nextword-qa-1M.h5
# Epoch 45/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.9753
#
# Epoch 00045: loss improved from 1.98174 to 1.97533, saving model to nextword-qa-1M.h5
# Epoch 46/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.9786
#
# Epoch 00046: loss did not improve from 1.97533
# Epoch 47/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.9546
#
# Epoch 00047: loss improved from 1.97533 to 1.95459, saving model to nextword-qa-1M.h5
# Epoch 48/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.9570
#
# Epoch 00048: loss did not improve from 1.95459
# Epoch 49/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9732
#
# Epoch 00049: loss did not improve from 1.95459
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9573
#
# Epoch 00050: loss did not improve from 1.95459
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 5
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 3s 29ms/step - loss: 9.4234
#
# Epoch 00001: loss did not improve from 1.95459
# Epoch 2/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.0622
#
# Epoch 00002: loss did not improve from 1.95459
# Epoch 3/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.1976
#
# Epoch 00003: loss did not improve from 1.95459
# Epoch 4/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7159
#
# Epoch 00004: loss did not improve from 1.95459
# Epoch 5/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3519
#
# Epoch 00005: loss did not improve from 1.95459
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0481
#
# Epoch 00006: loss did not improve from 1.95459
# Epoch 7/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7862
#
# Epoch 00007: loss did not improve from 1.95459
# Epoch 8/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5521
#
# Epoch 00008: loss did not improve from 1.95459
# Epoch 9/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3608
#
# Epoch 00009: loss did not improve from 1.95459
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2002
#
# Epoch 00010: loss did not improve from 1.95459
# Epoch 11/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.0515
#
# Epoch 00011: loss did not improve from 1.95459
# Epoch 12/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.9270
#
# Epoch 00012: loss did not improve from 1.95459
# Epoch 13/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8232
#
# Epoch 00013: loss did not improve from 1.95459
# Epoch 14/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.7470
#
# Epoch 00014: loss did not improve from 1.95459
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6596
#
# Epoch 00015: loss did not improve from 1.95459
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5832
#
# Epoch 00016: loss did not improve from 1.95459
# Epoch 17/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5715
#
# Epoch 00017: loss did not improve from 1.95459
# Epoch 18/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4799
#
# Epoch 00018: loss did not improve from 1.95459
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4405
#
# Epoch 00019: loss did not improve from 1.95459
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3893
#
# Epoch 00020: loss did not improve from 1.95459
# Epoch 21/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3448
#
# Epoch 00021: loss did not improve from 1.95459
# Epoch 22/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3243
#
# Epoch 00022: loss did not improve from 1.95459
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2968
#
# Epoch 00023: loss did not improve from 1.95459
# Epoch 24/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2299
#
# Epoch 00024: loss did not improve from 1.95459
# Epoch 25/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2283
#
# Epoch 00025: loss did not improve from 1.95459
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2267
#
# Epoch 00026: loss did not improve from 1.95459
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1997
#
# Epoch 00027: loss did not improve from 1.95459
# Epoch 28/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1869
#
# Epoch 00028: loss did not improve from 1.95459
# Epoch 29/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1571
#
# Epoch 00029: loss did not improve from 1.95459
# Epoch 30/50
# 33/33 [==============================] - 0s 11ms/step - loss: 2.1596
#
# Epoch 00030: loss did not improve from 1.95459
# Epoch 31/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1240
#
# Epoch 00031: loss did not improve from 1.95459
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1118
#
# Epoch 00032: loss did not improve from 1.95459
# Epoch 33/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0841
#
# Epoch 00033: loss did not improve from 1.95459
# Epoch 34/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0779
#
# Epoch 00034: loss did not improve from 1.95459
# Epoch 35/50
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0626
#
# Epoch 00035: loss did not improve from 1.95459
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0715
#
# Epoch 00036: loss did not improve from 1.95459
# Epoch 37/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0679
#
# Epoch 00037: loss did not improve from 1.95459
# Epoch 38/50
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0685
#
# Epoch 00038: loss did not improve from 1.95459
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 39/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9232
#
# Epoch 00039: loss improved from 1.95459 to 1.92321, saving model to nextword-qa-1M.h5
# Epoch 40/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8993
#
# Epoch 00040: loss improved from 1.92321 to 1.89928, saving model to nextword-qa-1M.h5
# Epoch 41/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8876
#
# Epoch 00041: loss improved from 1.89928 to 1.88756, saving model to nextword-qa-1M.h5
# Epoch 42/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8789
#
# Epoch 00042: loss improved from 1.88756 to 1.87894, saving model to nextword-qa-1M.h5
# Epoch 43/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8732
#
# Epoch 00043: loss improved from 1.87894 to 1.87320, saving model to nextword-qa-1M.h5
# Epoch 44/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8691
#
# Epoch 00044: loss improved from 1.87320 to 1.86908, saving model to nextword-qa-1M.h5
# Epoch 45/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8639
#
# Epoch 00045: loss improved from 1.86908 to 1.86389, saving model to nextword-qa-1M.h5
# Epoch 46/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8614
#
# Epoch 00046: loss improved from 1.86389 to 1.86139, saving model to nextword-qa-1M.h5
# Epoch 47/50
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8557
#
# Epoch 00047: loss improved from 1.86139 to 1.85573, saving model to nextword-qa-1M.h5
# Epoch 48/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8528
#
# Epoch 00048: loss improved from 1.85573 to 1.85282, saving model to nextword-qa-1M.h5
# Epoch 49/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8498
#
# Epoch 00049: loss improved from 1.85282 to 1.84978, saving model to nextword-qa-1M.h5
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8476
#
# Epoch 00050: loss improved from 1.84978 to 1.84762, saving model to nextword-qa-1M.h5
# 6
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 2s 20ms/step - loss: 12.6293
#
# Epoch 00001: loss did not improve from 1.84762
# Epoch 2/50
# 33/33 [==============================] - 0s 10ms/step - loss: 8.6077
#
# Epoch 00002: loss did not improve from 1.84762
# Epoch 3/50
# 33/33 [==============================] - 0s 9ms/step - loss: 7.3030
#
# Epoch 00003: loss did not improve from 1.84762
# Epoch 4/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.7786
#
# Epoch 00004: loss did not improve from 1.84762
# Epoch 5/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.4681
#
# Epoch 00005: loss did not improve from 1.84762
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.2526
#
# Epoch 00006: loss did not improve from 1.84762
# Epoch 7/50
# 33/33 [==============================] - 0s 10ms/step - loss: 6.0760
#
# Epoch 00007: loss did not improve from 1.84762
# Epoch 8/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.9316
#
# Epoch 00008: loss did not improve from 1.84762
# Epoch 9/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.8057
#
# Epoch 00009: loss did not improve from 1.84762
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.6937
#
# Epoch 00010: loss did not improve from 1.84762
# Epoch 11/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.5939
#
# Epoch 00011: loss did not improve from 1.84762
# Epoch 12/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.4935
#
# Epoch 00012: loss did not improve from 1.84762
# Epoch 13/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.3999
#
# Epoch 00013: loss did not improve from 1.84762
# Epoch 14/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.3021
#
# Epoch 00014: loss did not improve from 1.84762
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.2093
#
# Epoch 00015: loss did not improve from 1.84762
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.1152
#
# Epoch 00016: loss did not improve from 1.84762
# Epoch 17/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.0214
#
# Epoch 00017: loss did not improve from 1.84762
# Epoch 18/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.9335
#
# Epoch 00018: loss did not improve from 1.84762
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.8491
#
# Epoch 00019: loss did not improve from 1.84762
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7701
#
# Epoch 00020: loss did not improve from 1.84762
# Epoch 21/50
# 33/33 [==============================] - 0s 8ms/step - loss: 4.6957
#
# Epoch 00021: loss did not improve from 1.84762
# Epoch 22/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.6268
#
# Epoch 00022: loss did not improve from 1.84762
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5603
#
# Epoch 00023: loss did not improve from 1.84762
# Epoch 24/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4941
#
# Epoch 00024: loss did not improve from 1.84762
# Epoch 25/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4293
#
# Epoch 00025: loss did not improve from 1.84762
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3673
#
# Epoch 00026: loss did not improve from 1.84762
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3061
#
# Epoch 00027: loss did not improve from 1.84762
# Epoch 28/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2497
#
# Epoch 00028: loss did not improve from 1.84762
# Epoch 29/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.1917
#
# Epoch 00029: loss did not improve from 1.84762
# Epoch 30/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1382
#
# Epoch 00030: loss did not improve from 1.84762
# Epoch 31/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0853
#
# Epoch 00031: loss did not improve from 1.84762
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0324
#
# Epoch 00032: loss did not improve from 1.84762
# Epoch 33/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9818
#
# Epoch 00033: loss did not improve from 1.84762
# Epoch 34/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9324
#
# Epoch 00034: loss did not improve from 1.84762
# Epoch 35/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8869
#
# Epoch 00035: loss did not improve from 1.84762
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8382
#
# Epoch 00036: loss did not improve from 1.84762
# Epoch 37/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7949
#
# Epoch 00037: loss did not improve from 1.84762
# Epoch 38/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7497
#
# Epoch 00038: loss did not improve from 1.84762
# Epoch 39/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7071
#
# Epoch 00039: loss did not improve from 1.84762
# Epoch 40/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6647
#
# Epoch 00040: loss did not improve from 1.84762
# Epoch 41/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6240
#
# Epoch 00041: loss did not improve from 1.84762
# Epoch 42/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5809
#
# Epoch 00042: loss did not improve from 1.84762
# Epoch 43/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5431
#
# Epoch 00043: loss did not improve from 1.84762
# Epoch 44/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5042
#
# Epoch 00044: loss did not improve from 1.84762
# Epoch 45/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.4658
#
# Epoch 00045: loss did not improve from 1.84762
# Epoch 46/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4261
#
# Epoch 00046: loss did not improve from 1.84762
# Epoch 47/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.3925
#
# Epoch 00047: loss did not improve from 1.84762
# Epoch 48/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3537
#
# Epoch 00048: loss did not improve from 1.84762
# Epoch 49/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3230
#
# Epoch 00049: loss did not improve from 1.84762
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2845
#
# Epoch 00050: loss did not improve from 1.84762
# 7
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 3s 27ms/step - loss: 12.9569
#
# Epoch 00001: loss did not improve from 1.84762
# Epoch 2/50
# 33/33 [==============================] - 0s 10ms/step - loss: 8.6807
#
# Epoch 00002: loss did not improve from 1.84762
# Epoch 3/50
# 33/33 [==============================] - 0s 10ms/step - loss: 7.3213
#
# Epoch 00003: loss did not improve from 1.84762
# Epoch 4/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.7676
#
# Epoch 00004: loss did not improve from 1.84762
# Epoch 5/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.4433
#
# Epoch 00005: loss did not improve from 1.84762
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.2068
#
# Epoch 00006: loss did not improve from 1.84762
# Epoch 7/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.0160
#
# Epoch 00007: loss did not improve from 1.84762
# Epoch 8/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.8479
#
# Epoch 00008: loss did not improve from 1.84762
# Epoch 9/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.6945
#
# Epoch 00009: loss did not improve from 1.84762
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.5541
#
# Epoch 00010: loss did not improve from 1.84762
# Epoch 11/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.4172
#
# Epoch 00011: loss did not improve from 1.84762
# Epoch 12/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.2830
#
# Epoch 00012: loss did not improve from 1.84762
# Epoch 13/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.1562
#
# Epoch 00013: loss did not improve from 1.84762
# Epoch 14/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.0379
#
# Epoch 00014: loss did not improve from 1.84762
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.9271
#
# Epoch 00015: loss did not improve from 1.84762
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.8328
#
# Epoch 00016: loss did not improve from 1.84762
# Epoch 17/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7422
#
# Epoch 00017: loss did not improve from 1.84762
# Epoch 18/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.6602
#
# Epoch 00018: loss did not improve from 1.84762
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5819
#
# Epoch 00019: loss did not improve from 1.84762
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5095
#
# Epoch 00020: loss did not improve from 1.84762
# Epoch 21/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4401
#
# Epoch 00021: loss did not improve from 1.84762
# Epoch 22/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3753
#
# Epoch 00022: loss did not improve from 1.84762
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3152
#
# Epoch 00023: loss did not improve from 1.84762
# Epoch 24/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2584
#
# Epoch 00024: loss did not improve from 1.84762
# Epoch 25/50
# 33/33 [==============================] - 0s 10ms/step - loss: 4.2030
#
# Epoch 00025: loss did not improve from 1.84762
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1510
#
# Epoch 00026: loss did not improve from 1.84762
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0948
#
# Epoch 00027: loss did not improve from 1.84762
# Epoch 28/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0435
#
# Epoch 00028: loss did not improve from 1.84762
# Epoch 29/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.9941
#
# Epoch 00029: loss did not improve from 1.84762
# Epoch 30/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9418
#
# Epoch 00030: loss did not improve from 1.84762
# Epoch 31/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8954
#
# Epoch 00031: loss did not improve from 1.84762
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8455
#
# Epoch 00032: loss did not improve from 1.84762
# Epoch 33/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7998
#
# Epoch 00033: loss did not improve from 1.84762
# Epoch 34/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7572
#
# Epoch 00034: loss did not improve from 1.84762
# Epoch 35/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7122
#
# Epoch 00035: loss did not improve from 1.84762
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6685
#
# Epoch 00036: loss did not improve from 1.84762
# Epoch 37/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6282
#
# ...
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2565
#
# Epoch 00026: loss did not improve from 1.84762
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2031
#
# Epoch 00027: loss did not improve from 1.84762
# Epoch 28/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1497
#
# Epoch 00028: loss did not improve from 1.84762
# Epoch 29/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1005
#
# Epoch 00029: loss did not improve from 1.84762
# Epoch 30/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0528
#
# Epoch 00030: loss did not improve from 1.84762
# Epoch 31/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0055
#
# Epoch 00031: loss did not improve from 1.84762
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9605
#
# Epoch 00032: loss did not improve from 1.84762
# Epoch 33/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9182
#
# Epoch 00033: loss did not improve from 1.84762
# Epoch 34/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8713
#
# Epoch 00034: loss did not improve from 1.84762
# Epoch 35/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8324
#
# Epoch 00035: loss did not improve from 1.84762
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7885
#
# Epoch 00036: loss did not improve from 1.84762
# Epoch 37/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7465
#
# Epoch 00037: loss did not improve from 1.84762
# Epoch 38/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.7070
#
# Epoch 00038: loss did not improve from 1.84762
# Epoch 39/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6644
#
# Epoch 00039: loss did not improve from 1.84762
# Epoch 40/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6267
#
# Epoch 00040: loss did not improve from 1.84762
# Epoch 41/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5866
#
# Epoch 00041: loss did not improve from 1.84762
# Epoch 42/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5492
#
# Epoch 00042: loss did not improve from 1.84762
# Epoch 43/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5114
#
# Epoch 00043: loss did not improve from 1.84762
# Epoch 44/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4704
#
# Epoch 00044: loss did not improve from 1.84762
# Epoch 45/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4330
#
# Epoch 00045: loss did not improve from 1.84762
# Epoch 46/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4033
#
# Epoch 00046: loss did not improve from 1.84762
# Epoch 47/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3637
#
# Epoch 00047: loss did not improve from 1.84762
# Epoch 48/50
# 33/33 [==============================] - 0s 8ms/step - loss: 3.3274
#
# Epoch 00048: loss did not improve from 1.84762
# Epoch 49/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2916
#
# Epoch 00049: loss did not improve from 1.84762
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2574
#
# Epoch 00050: loss did not improve from 1.84762
# 98
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 3s 27ms/step - loss: 12.4419
#
# Epoch 00001: loss did not improve from 1.84762
# Epoch 2/50
# 33/33 [==============================] - 0s 9ms/step - loss: 8.5369
#
# Epoch 00002: loss did not improve from 1.84762
# Epoch 3/50
# 33/33 [==============================] - 0s 9ms/step - loss: 7.2225
#
# Epoch 00003: loss did not improve from 1.84762
# Epoch 4/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.6993
#
# Epoch 00004: loss did not improve from 1.84762
# Epoch 5/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.3774
#
# Epoch 00005: loss did not improve from 1.84762
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.1448
#
# Epoch 00006: loss did not improve from 1.84762
# Epoch 7/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.9505
#
# Epoch 00007: loss did not improve from 1.84762
# Epoch 8/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.7816
#
# Epoch 00008: loss did not improve from 1.84762
# Epoch 9/50
# 33/33 [==============================] - 0s 8ms/step - loss: 5.6282
#
# Epoch 00009: loss did not improve from 1.84762
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.4933
#
# Epoch 00010: loss did not improve from 1.84762
# Epoch 11/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.3706
#
# Epoch 00011: loss did not improve from 1.84762
# Epoch 12/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.2593
#
# Epoch 00012: loss did not improve from 1.84762
# Epoch 13/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.1512
#
# Epoch 00013: loss did not improve from 1.84762
# Epoch 14/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.0468
#
# Epoch 00014: loss did not improve from 1.84762
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.9502
#
# Epoch 00015: loss did not improve from 1.84762
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.8555
#
# Epoch 00016: loss did not improve from 1.84762
# Epoch 17/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7638
#
# Epoch 00017: loss did not improve from 1.84762
# Epoch 18/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.6767
#
# Epoch 00018: loss did not improve from 1.84762
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5947
#
# Epoch 00019: loss did not improve from 1.84762
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5165
#
# Epoch 00020: loss did not improve from 1.84762
# Epoch 21/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4417
#
# Epoch 00021: loss did not improve from 1.84762
# Epoch 22/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3663
#
# Epoch 00022: loss did not improve from 1.84762
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2966
#
# Epoch 00023: loss did not improve from 1.84762
# Epoch 24/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2281
#
# Epoch 00024: loss did not improve from 1.84762
# Epoch 25/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1668
#
# Epoch 00025: loss did not improve from 1.84762
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1079
#
# Epoch 00026: loss did not improve from 1.84762
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0532
#
# Epoch 00027: loss did not improve from 1.84762
# Epoch 28/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9972
#
# Epoch 00028: loss did not improve from 1.84762
# Epoch 29/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9478
#
# Epoch 00029: loss did not improve from 1.84762
# Epoch 30/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8951
#
# Epoch 00030: loss did not improve from 1.84762
# Epoch 31/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8477
#
# Epoch 00031: loss did not improve from 1.84762
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8025
#
# Epoch 00032: loss did not improve from 1.84762
# Epoch 33/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7534
#
# Epoch 00033: loss did not improve from 1.84762
# Epoch 34/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7070
#
# Epoch 00034: loss did not improve from 1.84762
# Epoch 35/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6661
#
# Epoch 00035: loss did not improve from 1.84762
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6223
#
# Epoch 00036: loss did not improve from 1.84762
# Epoch 37/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5778
#
# Epoch 00037: loss did not improve from 1.84762
# Epoch 38/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5376
#
# Epoch 00038: loss did not improve from 1.84762
# Epoch 39/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4985
#
# Epoch 00039: loss did not improve from 1.84762
# Epoch 40/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4606
#
# Epoch 00040: loss did not improve from 1.84762
# Epoch 41/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4206
#
# Epoch 00041: loss did not improve from 1.84762
# Epoch 42/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3827
#
# Epoch 00042: loss did not improve from 1.84762
# Epoch 43/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3481
#
# Epoch 00043: loss did not improve from 1.84762
# Epoch 44/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3140
#
# Epoch 00044: loss did not improve from 1.84762
# Epoch 45/50
# 33/33 [==============================] - 0s 8ms/step - loss: 3.2768
#
# Epoch 00045: loss did not improve from 1.84762
# Epoch 46/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2441
#
# Epoch 00046: loss did not improve from 1.84762
# Epoch 47/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2111
#
# Epoch 00047: loss did not improve from 1.84762
# Epoch 48/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1761
#
# Epoch 00048: loss did not improve from 1.84762
# Epoch 49/50
# 33/33 [==============================] - 0s 8ms/step - loss: 3.1440
#
# Epoch 00049: loss did not improve from 1.84762
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1134
#
# Epoch 00050: loss did not improve from 1.84762
# 99
#
#
#
#
# Epoch 1/50
# 33/33 [==============================] - 2s 22ms/step - loss: 13.5835
#
# Epoch 00001: loss did not improve from 1.84762
# Epoch 2/50
# 33/33 [==============================] - 0s 9ms/step - loss: 8.9848
#
# Epoch 00002: loss did not improve from 1.84762
# Epoch 3/50
# 33/33 [==============================] - 0s 9ms/step - loss: 7.6044
#
# Epoch 00003: loss did not improve from 1.84762
# Epoch 4/50
# 33/33 [==============================] - 0s 9ms/step - loss: 7.0663
#
# Epoch 00004: loss did not improve from 1.84762
# Epoch 5/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.7225
#
# Epoch 00005: loss did not improve from 1.84762
# Epoch 6/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.4453
#
# Epoch 00006: loss did not improve from 1.84762
# Epoch 7/50
# 33/33 [==============================] - 0s 9ms/step - loss: 6.1981
#
# Epoch 00007: loss did not improve from 1.84762
# Epoch 8/50
# 33/33 [==============================] - 0s 10ms/step - loss: 5.9785
#
# Epoch 00008: loss did not improve from 1.84762
# Epoch 9/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.7823
#
# Epoch 00009: loss did not improve from 1.84762
# Epoch 10/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.6087
#
# Epoch 00010: loss did not improve from 1.84762
# Epoch 11/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.4513
#
# Epoch 00011: loss did not improve from 1.84762
# Epoch 12/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.3107
#
# Epoch 00012: loss did not improve from 1.84762
# Epoch 13/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.1865
#
# Epoch 00013: loss did not improve from 1.84762
# Epoch 14/50
# 33/33 [==============================] - 0s 9ms/step - loss: 5.0687
#
# Epoch 00014: loss did not improve from 1.84762
# Epoch 15/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.9680
#
# Epoch 00015: loss did not improve from 1.84762
# Epoch 16/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.8734
#
# Epoch 00016: loss did not improve from 1.84762
# Epoch 17/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7876
#
# Epoch 00017: loss did not improve from 1.84762
# Epoch 18/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7065
#
# Epoch 00018: loss did not improve from 1.84762
# Epoch 19/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.6316
#
# Epoch 00019: loss did not improve from 1.84762
# Epoch 20/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5593
#
# Epoch 00020: loss did not improve from 1.84762
# Epoch 21/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4922
#
# Epoch 00021: loss did not improve from 1.84762
# Epoch 22/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.4301
#
# Epoch 00022: loss did not improve from 1.84762
# Epoch 23/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3645
#
# Epoch 00023: loss did not improve from 1.84762
# Epoch 24/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.3049
#
# Epoch 00024: loss did not improve from 1.84762
# Epoch 25/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.2471
#
# Epoch 00025: loss did not improve from 1.84762
# Epoch 26/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1864
#
# Epoch 00026: loss did not improve from 1.84762
# Epoch 27/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.1330
#
# Epoch 00027: loss did not improve from 1.84762
# Epoch 28/50
# 33/33 [==============================] - 0s 8ms/step - loss: 4.0782
#
# Epoch 00028: loss did not improve from 1.84762
# Epoch 29/50
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0222
#
# Epoch 00029: loss did not improve from 1.84762
# Epoch 30/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9693
#
# Epoch 00030: loss did not improve from 1.84762
# Epoch 31/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9190
#
# Epoch 00031: loss did not improve from 1.84762
# Epoch 32/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8665
#
# Epoch 00032: loss did not improve from 1.84762
# Epoch 33/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8166
#
# Epoch 00033: loss did not improve from 1.84762
# Epoch 34/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7694
#
# Epoch 00034: loss did not improve from 1.84762
# Epoch 35/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7183
#
# Epoch 00035: loss did not improve from 1.84762
# Epoch 36/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6696
#
# Epoch 00036: loss did not improve from 1.84762
# Epoch 37/50
# 33/33 [==============================] - 0s 10ms/step - loss: 3.6229
#
# Epoch 00037: loss did not improve from 1.84762
# Epoch 38/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5784
#
# Epoch 00038: loss did not improve from 1.84762
# Epoch 39/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5337
#
# Epoch 00039: loss did not improve from 1.84762
# Epoch 40/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4898
#
# Epoch 00040: loss did not improve from 1.84762
# Epoch 41/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4465
#
# Epoch 00041: loss did not improve from 1.84762
# Epoch 42/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4056
#
# Epoch 00042: loss did not improve from 1.84762
# Epoch 43/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.3677
#
# Epoch 00043: loss did not improve from 1.84762
# Epoch 44/50
# 33/33 [==============================] - 0s 8ms/step - loss: 3.3241
#
# Epoch 00044: loss did not improve from 1.84762
# Epoch 45/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2836
#
# Epoch 00045: loss did not improve from 1.84762
# Epoch 46/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2444
#
# Epoch 00046: loss did not improve from 1.84762
# Epoch 47/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2043
#
# Epoch 00047: loss did not improve from 1.84762
# Epoch 48/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1655
#
# Epoch 00048: loss did not improve from 1.84762
# Epoch 49/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1293
#
# Epoch 00049: loss did not improve from 1.84762
# Epoch 50/50
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0921
#
# Epoch 00050: loss did not improve from 1.84762

# %%
# https://stackoverflow.com/questions/26649716/how-to-show-pil-image-in-ipython-notebook
# tensorboard --logdir="./logsnextword1"
# http://DESKTOP-U3TSCVT:6006/

from IPython.display import Image 
pil_img = Image(filename='graph1.png')
display(pil_img)
